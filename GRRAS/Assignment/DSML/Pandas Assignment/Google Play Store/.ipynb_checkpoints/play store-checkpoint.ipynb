# %% [markdown]
# #### `Analyse play store dataset and write down conclusion of the analysis and also create plots if possible.`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df[:50]
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %% [markdown]
# ## que1 :- Which category of apps has big count ?

# %%
# cat = df["Category"].value_counts()
cat = df["Category"].value_counts().idxmax()
cat
# Out:
# 'FAMILY'

# %%
cat.head(1)
# Out:
# Category
# FAMILY    1972
# Name: count, dtype: int64

# %% [markdown]
# ## que2 :- Top 5 Highest rating app from each category?

# %%
df["Category"].reset_index()
# Out:
#        index             Category
# 0          0       ART_AND_DESIGN
# 1          1       ART_AND_DESIGN
# 2          2       ART_AND_DESIGN
# 3          3       ART_AND_DESIGN
# 4          4       ART_AND_DESIGN
# ...      ...                  ...
# 10836  10836               FAMILY
# 10837  10837               FAMILY
# 10838  10838              MEDICAL
# 10839  10839  BOOKS_AND_REFERENCE
# 10840  10840            LIFESTYLE
#
# [10841 rows x 2 columns]

# %% [markdown]
# ## que3 :- Find number of free and paid apps.

# %%
# types = df.groupby("Type").size().reset_index().set_index("Type")
types = df["Type"].value_counts().reset_index().set_index("Type")
free = types.loc["Free"]
paid = types.loc["Paid"]
print(f"Total numbers of Free Apps are {free}")
print(f"Total numbers of Free Apps are {paid}")
# Out:
# Total numbers of Free Apps are count    10039
# Name: Free, dtype: int64
# Total numbers of Free Apps are count    800
# Name: Paid, dtype: int64

# %% [markdown]
# ## que4 :- Number of highest rating apps?

# %% [markdown]
# ## que5 :- Find the Category & ratings of apps which are paid.

# %% [markdown]
# ## que 6 :- Find the name of the apps which has installed >500,000 and rating >=4.0

# %% [markdown]
# ## create your own question and solve them here.
