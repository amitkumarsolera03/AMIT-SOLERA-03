# %% [markdown]
# ## Steps to build End to End ML Project
#
#     supervise , unsupervise , reinforcement , deeplearning , gen-AI

# %% [markdown]
# Making predictions based on Past experiences (Data)
#
# - A computer program which improves its performance (P) on a given task(T) with experience

# %% [markdown]
# **Task ---> Free Launch Theorem**

# %% [markdown]
# ## Supervise ML
#
#     Lable data , we train ML model with input and output examples
#
#     input is known as features
#     output is known as lable , target
#
#     A ML program which trained using features and lables known as superviesd model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.shape
# Out:
# (398, 9)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ## 1. Understand the problem / looking at the Big Pictures
#
#     Get domain Knowledge
#
#     objective and expectation
#
#         mpg prediction based on given features

# %% [markdown]
# ### EDA

# %%
sns.pairplot(mpg)
plt.show()

# Warning - Not use for big data

# %% [markdown]
# ### Lable - mpg(Y)
#
# ### Features - X

# %%
features = ["cylinders",	"displacement",	"horsepower","weight","acceleration" ,"model_year"]

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
for feature in features:
    r = np.corrcoef(x = mpg[feature] , y=mpg["mpg"])[0,1]
    plt.scatter(mpg[feature] , mpg["mpg"] , label=f"r={r:2f}")
    plt.xlabel(feature)
    plt.ylabel("mpg")
    plt.grid()
    plt.title(f"{feature} vs mpg")
    plt.legend()
    plt.show()

# %%
sns.set_theme()
plt.figure(figsize=(12,5))
sns.boxplot(y="mpg" , hue="cylinders" , data = mpg, palette="coolwarm")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(y="mpg" , hue="model_year" , data = mpg, palette="coolwarm")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.boxplot(y="mpg" , hue="origin" , data = mpg, palette="coolwarm")
plt.show()

# %% [markdown]
# ## Encoding

# %%
mpg["origin"].map({"usa":1 , "europe":2,"japan" :3})
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %%
mpg["origin"].apply(lambda v:3 if  v == "japan" else 2 if v == "europe" else 1)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %% [markdown]
# **24/07/2025**

# %%
plt.figure(figsize = (12,5),dpi = 210)
sns.scatterplot(x="horsepower" , y="mpg" , data=mpg , hue = "model_year" , palette="rainbow",style="origin", markers=True)
plt.show()

# %%
mpg["origin"].value_counts()/mpg.shape[0]
# Out:
# origin
# usa       0.625628
# japan     0.198492
# europe    0.175879
# Name: count, dtype: float64

# %%
features = ["cylinders",	"displacement",	"horsepower","weight","acceleration" ,"model_year"]
target = "origin"

# %%
from sklearn.model_selection import train_test_split

# %%
X = mpg[features]
y = mpg["mpg"]

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y , test_size=0.2)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
X_train.describe().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_c56e7_row0_col0, #T_c56e7_row0_col2, #T_c56e7_row0_col4, #T_c56e7_row0_col5, #T_c56e7_row7_col1, #T_c56e7_row7_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c56e7_row0_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c56e7_row0_col3, #T_c56e7_row2_col0, #T_c56e7_row2_col2, #T_c56e7_row2_col4, #T_c56e7_row2_col5, #T_c56e7_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c56e7_row1_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c56e7_row1_col1, #T_c56e7_row6_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c56e7_row1_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c56e7_row1_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c56e7_row1_col4, #T_c56e7_row5_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c56e7_row1_col5, #T_c56e7_row5_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c56e7_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c56e7_row2_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c56e7_row3_col0, #T_c56e7_row4_col0, #T_c56e7_row5_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c56e7_row3_col2, #T_c56e7_row6_col0, #T_c56e7_row7_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c56e7_row3_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_c56e7_row3_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c56e7_row3_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c56e7_row4_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c56e7_row4_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c56e7_row4_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_c56e7_row4_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c56e7_row4_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c56e7_row5_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_c56e7_row5_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_c56e7_row5_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c56e7_row6_col1 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_c56e7_row6_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c56e7_row6_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c56e7_row6_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_c56e7_row7_col2 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_c56e7_row7_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c56e7_row7_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# </style>
# <table id="T_c56e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c56e7_level0_col0" class="col_heading level0 col0" >cylinders</th>
#       <th id="T_c56e7_level0_col1" class="col_heading level0 col1" >displacement</th>
#       <th id="T_c56e7_level0_col2" class="col_heading level0 col2" >horsepower</th>
#       <th id="T_c56e7_level0_col3" class="col_heading level0 col3" >weight</th>
#       <th id="T_c56e7_level0_col4" class="col_heading level0 col4" >acceleration</th>
#       <th id="T_c56e7_level0_col5" class="col_heading level0 col5" >model_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c56e7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c56e7_row0_col0" class="data row0 col0" >318.000000</td>
#       <td id="T_c56e7_row0_col1" class="data row0 col1" >318.000000</td>
#       <td id="T_c56e7_row0_col2" class="data row0 col2" >314.000000</td>
#       <td id="T_c56e7_row0_col3" class="data row0 col3" >318.000000</td>
#       <td id="T_c56e7_row0_col4" class="data row0 col4" >318.000000</td>
#       <td id="T_c56e7_row0_col5" class="data row0 col5" >318.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c56e7_row1_col0" class="data row1 col0" >5.433962</td>
#       <td id="T_c56e7_row1_col1" class="data row1 col1" >192.410377</td>
#       <td id="T_c56e7_row1_col2" class="data row1 col2" >105.057325</td>
#       <td id="T_c56e7_row1_col3" class="data row1 col3" >2956.383648</td>
#       <td id="T_c56e7_row1_col4" class="data row1 col4" >15.454717</td>
#       <td id="T_c56e7_row1_col5" class="data row1 col5" >75.993711</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c56e7_row2_col0" class="data row2 col0" >1.722108</td>
#       <td id="T_c56e7_row2_col1" class="data row2 col1" >106.896921</td>
#       <td id="T_c56e7_row2_col2" class="data row2 col2" >40.466172</td>
#       <td id="T_c56e7_row2_col3" class="data row2 col3" >857.536331</td>
#       <td id="T_c56e7_row2_col4" class="data row2 col4" >2.747714</td>
#       <td id="T_c56e7_row2_col5" class="data row2 col5" >3.724752</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c56e7_row3_col0" class="data row3 col0" >3.000000</td>
#       <td id="T_c56e7_row3_col1" class="data row3 col1" >68.000000</td>
#       <td id="T_c56e7_row3_col2" class="data row3 col2" >46.000000</td>
#       <td id="T_c56e7_row3_col3" class="data row3 col3" >1613.000000</td>
#       <td id="T_c56e7_row3_col4" class="data row3 col4" >8.000000</td>
#       <td id="T_c56e7_row3_col5" class="data row3 col5" >70.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c56e7_row4_col0" class="data row4 col0" >4.000000</td>
#       <td id="T_c56e7_row4_col1" class="data row4 col1" >98.000000</td>
#       <td id="T_c56e7_row4_col2" class="data row4 col2" >75.000000</td>
#       <td id="T_c56e7_row4_col3" class="data row4 col3" >2216.250000</td>
#       <td id="T_c56e7_row4_col4" class="data row4 col4" >13.625000</td>
#       <td id="T_c56e7_row4_col5" class="data row4 col5" >73.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_c56e7_row5_col0" class="data row5 col0" >4.000000</td>
#       <td id="T_c56e7_row5_col1" class="data row5 col1" >144.500000</td>
#       <td id="T_c56e7_row5_col2" class="data row5 col2" >95.000000</td>
#       <td id="T_c56e7_row5_col3" class="data row5 col3" >2782.000000</td>
#       <td id="T_c56e7_row5_col4" class="data row5 col4" >15.500000</td>
#       <td id="T_c56e7_row5_col5" class="data row5 col5" >76.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_c56e7_row6_col0" class="data row6 col0" >8.000000</td>
#       <td id="T_c56e7_row6_col1" class="data row6 col1" >293.250000</td>
#       <td id="T_c56e7_row6_col2" class="data row6 col2" >129.000000</td>
#       <td id="T_c56e7_row6_col3" class="data row6 col3" >3597.250000</td>
#       <td id="T_c56e7_row6_col4" class="data row6 col4" >17.000000</td>
#       <td id="T_c56e7_row6_col5" class="data row6 col5" >79.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c56e7_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_c56e7_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_c56e7_row7_col1" class="data row7 col1" >455.000000</td>
#       <td id="T_c56e7_row7_col2" class="data row7 col2" >230.000000</td>
#       <td id="T_c56e7_row7_col3" class="data row7 col3" >5140.000000</td>
#       <td id="T_c56e7_row7_col4" class="data row7 col4" >23.700000</td>
#       <td id="T_c56e7_row7_col5" class="data row7 col5" >82.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
features
# Out:
# ['cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year']

# %%
num_features = ["cylinders",
 'displacement',
 'horsepower',
 'weight',
 'acceleration']

# %%
cat_features = ["origin"]

# %%
from sklearn. import Min
